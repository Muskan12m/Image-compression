# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import svd
from PIL import Image

# %%
from ipywidgets import interact, interactive, interact_manual
import ipywidgets as widgets
from IPython.display import display
# %matplotlib inline

# %%
# replace images with the image you want to compress
images = {
    "Beautiful Nature": np.asarray(Image.open('/content/nature1.jpg')),
    "Tree in Nature": np.asarray(Image.open('/content/nature2.jpg')),
    "Dog": np.asarray(Image.open('/content/animal1.jpg')),
    "Lion": np.asarray(Image.open('/content/animal2.jpg')),
    "Jackals": np.asarray(Image.open('/content/animal3.jpg')),
    "Flower (white)": np.asarray(Image.open('/content/flower1.jpg')),
    "Flower (coloured)": np.asarray(Image.open('/content/flower2.jpeg')),
    "Rahul Dangi": np.asarray(Image.open('/content/developer.jpg')),
}

# %%
BeautifulNature=Image.open('/content/nature1.jpg')
TreeinNature=Image.open('/content/nature2.jpg')
Dog=Image.open('/content/animal1.jpg')
Lion=Image.open('/content/animal2.jpg')
Jackals=Image.open('/content/animal3.jpg')
Flowerwhite=Image.open('/content/flower1.jpg')
Flowercoloured=Image.open('/content/flower2.jpeg')
RahulDangi=Image.open('/content/developer.jpg')

# %%
import os
print(os.path.getsize('/content/nature1.jpg'))
print(os.path.getsize('/content/nature2.jpg'))
print(os.path.getsize('/content/animal2.jpg'))
print(os.path.getsize('/content/animal3.jpg'))
# Out:
# 13186
# 10239
# 35560
# 8486

# %%
def show_images(img_name):
    'It will show image in widgets'
    #print("Loading...")
    plt.title("Image Name: "+img_name+"\n")
    plt.imshow(images[img_name])
    plt.axis('off')
    plt.show()

# %%
interact(show_images, img_name=list(images.keys()))
# Out:
# interactive(children=(Dropdown(description='img_name', options=('Beautiful Nature', 'Tree in Nature', 'Dog', '…
# <function __main__.show_images>

# %%
compressed_image = None
text = None

# %%
def on_save_clicked(b):
    img_name = text.value.split()[0]
    print("saving image...")
    compressed_image.save(img_name+".jpg")
    print("image saved.")
    
    
def compress_image(img_name, k):
    #print("processing...")
    global text
    global compressed_image
    img = images[img_name]
    
    r = img[:,:,0]
    g = img[:,:,1]
    b = img[:,:,2]
    
    #print("compressing...")
    ur,sr,vr = svd(r, full_matrices=False)
    ug,sg,vg = svd(g, full_matrices=False)
    ub,sb,vb = svd(b, full_matrices=False)
    rr = np.dot(ur[:,:k],np.dot(np.diag(sr[:k]), vr[:k,:]))
    rg = np.dot(ug[:,:k],np.dot(np.diag(sg[:k]), vg[:k,:]))
    rb = np.dot(ub[:,:k],np.dot(np.diag(sb[:k]), vb[:k,:]))
    
    #print("arranging...")
    rimg = np.zeros(img.shape)
    rimg[:,:,0] = rr
    rimg[:,:,1] = rg
    rimg[:,:,2] = rb
    
    for ind1, row in enumerate(rimg):
        for ind2, col in enumerate(row):
            for ind3, value in enumerate(col):
                if value < 0:
                    rimg[ind1,ind2,ind3] = abs(value)
                if value > 255:
                    rimg[ind1,ind2,ind3] = 255

    compressed_image = rimg.astype(np.uint8)
    
    plt.title("Image Name: "+img_name+"\n")
    plt.imshow(compressed_image)
    plt.axis('off')
    plt.show()
    
    save = widgets.Button(description="Save image!", button_style='danger')
    save.on_click(on_save_clicked)
    
    compressed_image = Image.fromarray(compressed_image)
    
    text = widgets.Text(value="image_save",placeholder='Enter image name...',description='Image name')
    display(text)
    display(save)

# %%
interact(compress_image, img_name=list(images.keys()), k = (0,200))
# Out:
# interactive(children=(Dropdown(description='img_name', options=('Beautiful Nature', 'Tree in Nature', 'Dog', '…
# <function __main__.compress_image>

# %%
from io import BytesIO
img_file = BytesIO()
compressed_image.save(img_file,'png')
img_file.tell()
# Out:
# 95102
